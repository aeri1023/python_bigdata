# %%
import pandas as pd

# %%
hospital = pd.read_csv(u'서울시 동물병원 정보.csv',encoding='utf-8')
hospital
# Out:
#         시군구코드      신고일자               업소명  영업상태코드 영업상태  휴업시작일자  휴업종료일자  \
# 0     3110000  20081126           이강신동물병원       2   폐업     NaN     NaN
# 1     3210000  19840109           이성환동물병원       2   폐업     NaN     NaN
# 2     3140000  20140114          리베동물의료센터       2   폐업     NaN     NaN
# 3     3210000  20020923   My Friends 동물병원       2   폐업     NaN     NaN
# 4     3110000  20031114            우신동물병원       0   정상     NaN     NaN
# 5     3110000  20040213           패미원동물병원       2   폐업     NaN     NaN
# 6     3110000  20040218           에이스동물병원       2   폐업     NaN     NaN
# 7     3210000  20050901            반포동물병원       2   폐업     NaN     NaN
# 8     3210000  20051209         우성메디펫동물병원       2   폐업     NaN     NaN
# 9     3210000  20051230           다니엘동물병원       0   정상     NaN     NaN
# 10    3210000  20060329           스누피동물병원       2   폐업     NaN     NaN
# 11    3210000  20040409            서울동물병원       2   폐업     NaN     NaN
# ...

# %%
hospital.columns
# Out:
# Index([u'시군구코드', u'신고일자', u'업소명', u'영업상태코드', u'영업상태', u'휴업시작일자', u'휴업종료일자',
#        u'폐업일자', u'재개업일자', u'행정처분일자', u'행정처분사유', u'전화번호', u'면적(㎡)', u'건물용도',
#        u'건물구조', u'지하층', u'지상층', u'건물도시계획', u'건물주변환경', u'신고면허세종호', u'우편번호(지번)'],
#       dtype='object')

# %%
hospital=hospital.loc[(hospital[u'영업상태'].str.contains(u'정상'))]

# %%
hospital2=hospital[[u'시군구코드',u'신고일자',u'업소명',u'영업상태코드',u'영업상태']]

# %%
hospital2.head()
# Out:
#       시군구코드      신고일자      업소명  영업상태코드 영업상태
# 4   3110000  20031114   우신동물병원       0   정상
# 9   3210000  20051230  다니엘동물병원       0   정상
# 12  3210000  20040414  이상록동물병원       0   정상
# 18  3210000  20030113    수동물병원       0   정상
# 33  3110000  20040608  메디펫동물병원       0   정상

# %%
code = pd.read_excel(u'[붙임1]지방행정데이터개방_자치단체코드목록.xlsx',encoding='utf-8')
code
# Out:
#       번호      시도명  시도(자치단체)코드  시군구(자치단체)코드  시군구명
# 0      1  세종특별자치시   5690000.0          NaN   NaN
# 1      2    서울특별시   6110000.0    3000000.0   종로구
# 2      3      NaN         NaN    3010000.0    중구
# 3      4      NaN         NaN    3240000.0   강동구
# 4      5      NaN         NaN    3230000.0   송파구
# 5      6      NaN         NaN    3220000.0   강남구
# 6      7      NaN         NaN    3210000.0   서초구
# 7      8      NaN         NaN    3200000.0   관악구
# 8      9      NaN         NaN    3190000.0   동작구
# 9     10      NaN         NaN    3180000.0  영등포구
# 10    11      NaN         NaN    3170000.0   금천구
# 11    12      NaN         NaN    3160000.0   구로구
# 12    13      NaN         NaN    3150000.0   강서구
# 13    14      NaN         NaN    3140000.0   양천구
# 14    15      NaN         NaN    3130000.0   마포구
# 15    16      NaN         NaN    3120000.0  서대문구
# 16    17      NaN         NaN    3110000.0   은평구
# 17    18      NaN         NaN    3100000.0   노원구
# ...

# %%
code = code.loc[1:25,]
# Out:
#    번호    시도명  시도(자치단체)코드  시군구(자치단체)코드 시군구명
# 1   2  서울특별시   6110000.0    3000000.0  종로구
# 2   3    NaN         NaN    3010000.0   중구
# 3   4    NaN         NaN    3240000.0  강동구
# 4   5    NaN         NaN    3230000.0  송파구
# 5   6    NaN         NaN    3220000.0  강남구

# %%
print hospital[u"시군구코드"]
# Out:
# 4       3110000
# 9       3210000
# 12      3210000
# 18      3210000
# 33      3110000
# 39      3110000
# 40      3110000
# 47      3110000
# 50      3100000
# 51      3100000
# 52      3100000
# 56      3100000
# 59      3100000
# 63      3100000
# 67      3110000
# 69      3110000
# 70      3110000
# 73      3110000
# 74      3110000
# 76      3100000
# 77      3100000
# 80      3060000
# 81      3060000
# 83      3060000
# 88      3060000
# 89      3080000
# 90      3080000
# 91      3080000
# 96      3080000
# 98      3010000
#          ...
# 1799    3050000
# 1800    3110000
# 1801    3220000
# 1802    3030000
# 1803    3100000
# 1804    3190000
# 1806    3080000
# 1807    3210000
# 1808    3070000
# 1809    3160000
# 1810    3170000
# 1811    3110000
# 1812    3180000
# 1813    3180000
# 1814    3030000
# 1816    3020000
# 1817    3210000
# 1818    3210000
# 1819    3170000
# 1820    3040000
# 1821    3060000
# 1822    3070000
# 1823    3240000
# 1824    3220000
# ...

# %%
hospital2.head()
# Out:
#       시군구코드      신고일자      업소명  영업상태코드 영업상태  \
# 4   3110000  20031114   우신동물병원       0   정상
# 9   3210000  20051230  다니엘동물병원       0   정상
# 12  3210000  20040414  이상록동물병원       0   정상
# 18  3210000  20030113    수동물병원       0   정상
# 33  3110000  20040608  메디펫동물병원       0   정상
#
#                                                   시군구
# 4   {u'code': [3000000, 3010000, 3240000, 3230000,...
# 9   {u'code': [3000000, 3010000, 3240000, 3230000,...
# 12  {u'code': [3000000, 3010000, 3240000, 3230000,...
# 18  {u'code': [3000000, 3010000, 3240000, 3230000,...
# 33  {u'code': [3000000, 3010000, 3240000, 3230000,...

# %%
code1=dict(zip(codekey,codeval))

# %%
codekey = list(code[u'시군구(자치단체)코드'])
codeval = list(code[u'시군구명'])

# %%
code[u'시군구(자치단체)코드']= code[u'시군구(자치단체)코드'].astype(int)

# %%
code1
# Out:
# {3000000.0: u'\uc885\ub85c\uad6c',
#  3010000.0: u'\uc911\uad6c',
#  3020000.0: u'\uc6a9\uc0b0\uad6c',
#  3030000.0: u'\uc131\ub3d9\uad6c',
#  3040000.0: u'\uad11\uc9c4\uad6c',
#  3050000.0: u'\ub3d9\ub300\ubb38\uad6c',
#  3060000.0: u'\uc911\ub791\uad6c',
#  3070000.0: u'\uc131\ubd81\uad6c',
#  3080000.0: u'\uac15\ubd81\uad6c',
#  3090000.0: u'\ub3c4\ubd09\uad6c',
#  3100000.0: u'\ub178\uc6d0\uad6c',
#  3110000.0: u'\uc740\ud3c9\uad6c',
#  3120000.0: u'\uc11c\ub300\ubb38\uad6c',
#  3130000.0: u'\ub9c8\ud3ec\uad6c',
#  3140000.0: u'\uc591\ucc9c\uad6c',
#  3150000.0: u'\uac15\uc11c\uad6c',
#  3160000.0: u'\uad6c\ub85c\uad6c',
#  3170000.0: u'\uae08\ucc9c\uad6c',
#  3180000.0: u'\uc601\ub4f1\ud3ec\uad6c',
#  3190000.0: u'\ub3d9\uc791\uad6c',
#  3200000.0: u'\uad00\uc545\uad6c',
#  3210000.0: u'\uc11c\ucd08\uad6c',
#  3220000.0: u'\uac15\ub0a8\uad6c',
#  3230000.0: u'\uc1a1\ud30c\uad6c',
#  3240000.0: u'\uac15\ub3d9\uad6c'}

# %%
hospital2["시군구"]=hospital2["시군구코드"].apply(lambda x:code1[x])
# Out:
# C:\Users\go113\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hospital2
# Out:
#         시군구코드      신고일자               업소명  영업상태코드 영업상태   시군구
# 4     3110000  20031114            우신동물병원       0   정상   은평구
# 9     3210000  20051230           다니엘동물병원       0   정상   서초구
# 12    3210000  20040414           이상록동물병원       0   정상   서초구
# 18    3210000  20030113             수동물병원       0   정상   서초구
# 33    3110000  20040608           메디펫동물병원       0   정상   은평구
# 39    3110000  20050816         한수24시동물병원       0   정상   은평구
# 40    3110000  20060126            로얄동물병원       0   정상   은평구
# 47    3110000  20021203      금쪽같은내새끼 동물병원       0   정상   은평구
# 50    3100000  20060127           LK 동물병원       0   정상   노원구
# 51    3100000  20060201           브라운동물병원       0   정상   노원구
# 52    3100000  20060407           수락 동물병원       0   정상   노원구
# 56    3100000  19990521            은빛동물병원       0   정상   노원구
# 59    3100000  20010523            미래동물병원       0   정상   노원구
# 63    3100000  20040401           스누피동물병원       0   정상   노원구
# ...

# %%
hospital2.to_csv(u"동물병원_정제.csv",encoding='utf-8')

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
hos=list(hospital2['시군구'])
d=dict()
for sent in hos:
    for w in sent.split():
        if w not in d:
            d[w]=1
        else:
            d[w]=d[w]+1
d1 = dict()
for key, value in d.iteritems():
    if value>1:
        d1[key]=value
        print key, value
# Out:
# 영등포구 29
# 광진구 39
# 용산구 29
# 강북구 24
# 종로구 9
# 성북구 32
# 강동구 45
# 송파구 62
# 서대문구 26
# 강서구 47
# 구로구 23
# 강남구 75
# 중구 13
# 은평구 36
# 관악구 28
# 노원구 37
# 중랑구 30
# 금천구 15
# 도봉구 22
# 동작구 24
# 양천구 44
# 동대문구 23
# 성동구 32
# 마포구 43
# 서초구 49

# %%
plt.xlabel(u'동물병원 수',fontsize=14)
plt.ylabel(u'구별',fontsize=14)
plt.barh(range(len(d1.values())), d1.values(), color = 'darkblue')
plt.yticks(range(len(d1.values())),d1.keys())
plt.show()

# %%
import googlemaps
gmaps_key="AIzaSyCYtAsPd-_neuWjw1wC5gyLsr8I3Qf5m0g"
gmaps=googlemaps.Client(key=gmaps_key)

# %%
hos=pd.DataFrame({'lat':hos_lat, 'lng':hos_lng})
hos2=hospital2.join(hos,how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8ddc39b90491> in <module>()
# ----> 1 hos=pd.DataFrame({'lat':hos_lat, 'lng':hos_lng})
#       2 hos2=hospital2.join(hos,how='left')
#
# NameError: name 'hos_lat' is not defined

# %%
hos2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4d8528c8eb6b> in <module>()
# ----> 1 hos2.head()
#
# NameError: name 'hos2' is not defined

# %%
hos2=hos2.dropna()

# %%
hos2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d8528c8eb6b> in <module>()
# ----> 1 hos2.head()
#
# NameError: name 'hos2' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

def hospital_clean():
    hospital= pd.read_csv(u'서울시 동물병원 정보.csv',encoding='utf-8')
    hospital = hospital.loc[(hospital[u'영업상태'].str.contains(u'정상'))][[u'시군구코드',u'신고일자',u'업소명',u'영업상태코드',u'영업상태']]
    code = pd.read_excel(u'[붙임1]지방행정데이터개방_자치단체코드목록.xlsx',encoding='utf-8')
    code = code.loc[1:25,]
    codekey = list(code[u'시군구(자치단체)코드'].astype(int))
    codeval = list(code[u'시군구명'])
    code=dict(zip(codekey,codeval))
    hospital[u"시군구"]=hospital[u"시군구코드"].apply(lambda x:code[x])
    return hospital

def fre_hospital(data_hospital):
    hos=list(hospital[u'시군구'])
    d=dict()
    for sent in hos:
        for w in sent.split():
            if w not in d:
                d[w]=1
            else:
                d[w]=d[w]+1
    d_value = d.values()
    d_value.sort(reverse=True)
    num = d_value[10]
    d1 = dict()
    for key, value in d.iteritems():
        if value>=num:
            d1[key]=value
    plt.xlabel(u'동물병원 수',fontsize=14)
    plt.ylabel(u'구별',fontsize=14)
    plt.barh(range(len(d1.values())), d1.values(), color = 'darkblue')
    plt.yticks(range(len(d1.values())),d1.keys())
    plt.savefig("hospital_gu.png")
    plt.show()
    
def main():
    fre_hospital(hospital_clean)
if __name__=="__main__":
    main()

# %%
fre_hospital(hospital_clean())
# Out:
# 32

# %%
d2 =[29, 39, 29, 24, 9, 32, 45, 62, 26, 47, 23, 75, 13, 36, 28, 37, 30, 15, 22, 24, 44, 23, 32, 43, 49]

# %%
d2.sort(reverse=True)
d2
# Out:
# [75,
#  62,
#  49,
#  47,
#  45,
#  44,
#  43,
#  39,
#  37,
#  36,
#  32,
#  32,
#  30,
#  29,
#  29,
#  28,
#  26,
#  24,
#  24,
#  23,
#  23,
#  22,
#  15,
#  13,
#  9]

# %%
a=sorted(a.items(), key=operator.itemgetter(1))

# %%
a
# Out:
# [('C', 70), ('B', 80), ('A', 90)]
